# %% [markdown]
# ## 🎯 Exercícios 🎯 <a class="anchor" id="cinco"></a>

# %% [markdown]
# - Crie duas series aleatorias com 30 numeros, no intervalo 20 a 50 cada  ds1 ds2
# - Crie uma nova serie com o nome g_than com a comparação entre a s1 e a s2
# - Crie uma nova serie com o nome ds_sum com a soma das duas series
# - Apresente o desvio padrão da serie ds_sum
# - Crie uma nova serie com 30 strings de 5 caracteres aleatorios (Dica. random.choice + string.ascii_lowercase)
# - Crie uma lista com todas as series criadas
# - Crie um dataframe com as suas series (Dica. pd.concat())
# - Coloque o nome de cada serie no novo dataframe (Dica .rename)

# %%
import random 
import string
import pandas as pd
import numpy as np

# %%
ds1 = pd.Series(np.random.randint(20,51,size = 8))
ds2 = pd.Series(np.random.randint(20,51,size = 8))

g_than = pd.Series(ds1 > ds2)

ds_sum = pd.Series(ds1 +ds2)

ds_sum.std()

# string_serie = pd.Series(random.choice(string.ascii_lowercase) for x in range(5) for j in range(5))

# str_list = []
# for i in range(8):
#     str = ""
#     for j in range(5):
#         str+= random.choice(string.ascii_lowercase)
#     str_list.append(str)

str_list = []
for i in range(8):
    str_list.append((''.join((random.choice(string.ascii_lowercase)) for x in range(5))))
string_serie = pd.Series(str_list)


lista =[ds1,ds2,g_than,ds_sum,string_serie]

df = pd.concat(lista,axis = 1)

df.rename(columns={0:"ds1",1:"ds2",2:"g_than",3:"ds_sum",4:"string_serie"})
# Out:
#    ds1  ds2  g_than  ds_sum string_serie
# 0   25   49   False      74        wsech
# 1   23   34   False      57        qxcvy
# 2   20   24   False      44        pakkm
# 3   30   23    True      53        fnrla
# 4   42   38    True      80        hsrwy
# 5   41   33    True      74        ddott
# 6   32   30    True      62        hfeci
# 7   32   24    True      56        xjghn

# %% [markdown]
# Ver o dicionario sobre o arquivo
# https://dados.gov.br/dataset/preco-de-medicamentos-no-brasil-consumidor
#
# Prestar atenção no encoding ('iso-8859-15','utf-8','ascii') Googleit
#
#
# - 1.Carregar TA_PRECO_MEDICAMENTO.csv
#
#
# - 2.Revisar os dados (info, columns, head, tail...)
#
#
# - 3.Subset da Classe Terapeutica = N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS
#
#
# - 4.Fazer Transformaçoes da coluna de PMC12% para float
#
# - 5.Preço Máximo, Minimo e Mediaao Consumidor %12 da Classse Terapeutica = N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS e trazer a a linha com todas as infos do df
#
#
# - 6.Coletar 3 tipos de informações relevantes do dataset inteiro
#     - 6a Quantidade de Remedios por tipo tarja DICA (groupby)
#
#     - 6b Os 10 laboratorios com mais remedios em ordem decrescente DICA(sortby)
#
#     - 6c Faça um groupby Substância e tire um aggregate da coluna PMC 12% com min, max e mean
#
#     - 6d Informação que vocês acharem relevante

# %%
import pandas as pd

df = pd.read_csv(r'TA_PRECO_MEDICAMENTO.csv', sep = ";",encoding = 'latin-1', low_memory=False, decimal = ",")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26310 entries, 0 to 26309
# Data columns (total 40 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   SUBSTÂNCIA                                             26310 non-null  object
#  1   CNPJ                                                   26310 non-null  object
#  2   LABORATÓRIO                                            26310 non-null  object
#  3   CÓDIGO GGREM                                           26310 non-null  int64
#  4   REGISTRO                                               26310 non-null  object
#  5   EAN 1                                                  26310 non-null  object
#  6   EAN 2                                                  26310 non-null  object
#  7   EAN 3                                                  26310 non-null  object
#  8   PRODUTO                                                26310 non-null  object
#  9   APRESENTAÇÃO                                           26310 non-null  object
#  10  CLASSE TERAPÊUTICA                                     26310 non-null  object
#  11  TIPO DE PRODUTO (STATUS DO PRODUTO)                    26310 non-null  object
#  12  REGIME DE PREÇO                                        26310 non-null  object
#  13  PF Sem Impostos                                        26310 non-null  float64
#  14  PF 0%                                                  26310 non-null  float64
#  15  PF 12%                                                 25500 non-null  float64
#  16  PF 17%                                                 25500 non-null  float64
#  17  PF 17% ALC                                             25500 non-null  float64
#  18  PF 17,5%                                               25500 non-null  float64
#  19  PF 17,5% ALC                                           25500 non-null  float64
#  20  PF 18%                                                 25500 non-null  float64
#  21  PF 18% ALC                                             25500 non-null  float64
#  22  PF 20%                                                 25500 non-null  float64
#  23  PMC 0%                                                 21856 non-null  float64
#  24  PMC 12%                                                21597 non-null  float64
#  25  PMC 17%                                                21597 non-null  float64
#  26  PMC 17% ALC                                            21597 non-null  float64
#  27  PMC 17,5%                                              21597 non-null  float64
#  28  PMC 17,5% ALC                                          21597 non-null  float64
#  29  PMC 18%                                                21597 non-null  float64
#  30  PMC 18% ALC                                            21597 non-null  float64
#  31  PMC 20%                                                21597 non-null  float64
#  32  RESTRIÇÃO HOSPITALAR                                   26310 non-null  object
#  33  CAP                                                    26310 non-null  object
#  34  CONFAZ 87                                              26310 non-null  object
#  35  ICMS 0%                                                26310 non-null  object
#  36  ANÁLISE RECURSAL                                       162 non-null    object
#  37  LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  26310 non-null  object
#  38  COMERCIALIZAÇÃO 2020                                   26310 non-null  object
#  39  TARJA                                                  26310 non-null  object
# dtypes: float64(19), int64(1), object(20)
# memory usage: 8.0+ MB

# %%
df.head(4)
# Out:
#                                           SUBSTÂNCIA                CNPJ  \
# 0  SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  33.379.884/0001-96
# 1                   DIENOGESTE;VALERATO DE ESTRADIOL  56.990.534/0001-67
# 2             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 3             HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
#
#                                       LABORATÓRIO     CÓDIGO GGREM  \
# 0                        LABORATORIO SIMOES LTDA.  520500901178410
# 1  SCHERING DO BRASIL QUÍMICA E FARMACÊUTICA LTDA  530917060013104
# 2                      ORGANON FARMACÊUTICA LTDA.  525500402113310
# 3                      ORGANON FARMACÊUTICA LTDA.  525500401117312
#
#         REGISTRO          EAN 1       EAN 2       EAN 3       PRODUTO  \
# 0   057600510011  7896210500354      -           -       TALCO ALÍVIO
# 1  1002001390025  7896116871497      -           -          CHARMELIE
# 2  1002900020141  7897337705905      -           -         CO-RENITEC
# 3  1002900020158  7897337705912      -           -         CO-RENITEC
#
#                                         APRESENTAÇÃO  ... PMC 18% ALC PMC 20%  \
# 0                                 TALQUEIRA C/ 100 G  ...        8.50    9.70
# 1  COM REV A + COM REV B + COM REV C + COM REV D ...  ...      163.25  186.12
# 2               20 MG + 12,5 MG COM CT BL AL/AL X 30  ...       73.78   75.62
# 3                 10 MG + 25 MG COM CT BL AL/AL X 30  ...       48.45   49.67
#
#   RESTRIÇÃO HOSPITALAR  CAP  CONFAZ 87  ICMS 0%  ANÁLISE RECURSAL  \
# 0                  Não  Não        Não      Não               NaN
# 1                  Não  Não        Não      Não               NaN
# 2                  Não  Não        Não      Não               NaN
# 3                  Não  Não        Não      Não               NaN
#
#    LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 0                                           Negativa
# 1                                           Negativa
# 2                                           Positiva
# 3                                           Positiva
#
#    COMERCIALIZAÇÃO 2020              TARJA
# 0                   Não         Tarja -(*)
# 1                   Não  Tarja Vermelha(*)
# 2                   Não    Tarja  Vermelha
# 3                   Não    Tarja  Vermelha
#
# [4 rows x 40 columns]

# %%
df.tail()
# Out:
#                     SUBSTÂNCIA                CNPJ  \
# 26305  CLORIDRATO DE SEVELÂMER  13.078.518/0001-90
# 26306          INSULINA HUMANA  13.078.518/0001-90
# 26307          INSULINA HUMANA  13.078.518/0001-90
# 26308      ISOCONAZOL;ABARELIX  33.683.202/0001-34
# 26309       VALPROATO DE SÓDIO  49.475.833/0001-06
#
#                                              LABORATÓRIO     CÓDIGO GGREM  \
# 26305  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...  544018120000706
# 26306  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...  544018060000307
# 26307  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...  544018070000407
# 26308                             VISA ESTADUAL SP TESTE  542313030000103
# 26309                     BIOLAB SANUS FARMACÊUTICA LTDA  504118100064506
#
#             REGISTRO          EAN 1          EAN 2       EAN 3  \
# 26305  1988300020011  7898604730033         -           -
# 26306  1988300040012  7898604730064         -           -
# 26307  1988300050018  7898604730071         -           -
# 26308  9965400350064  2124165465465  2587469632224      -
# 26309         -       7896112401247         -           -
#
#                                  PRODUTO  \
# 26305            CLORIDRATO DE SEVELAMER
# 26306     BAHIAFARMA INSULINA HUMANA NPH
# 26307       BAHIAFARMA INSULINA HUMANA R
# 26308  PRODUTO DE MEDICAMENTO PARA TESTE
# 26309                    ÁCIDO VALPRÓICO
#
#                                  APRESENTAÇÃO  ... PMC 18% ALC PMC 20%  \
# 26305     800 MG COM REV CT FR PLAS OPC X 180  ...         NaN     NaN
# 26306  100 UI/ML SUS INJ CT FA VD INC X 10 ML  ...         NaN     NaN
# 26307  100 UI/ML SOL INJ CT FA VD INC X 10 ML  ...         NaN     NaN
# 26308                 APRESENTAÇÃO 01&nbsp;03  ...       12.35   14.07
# 26309  250 MG CAP GEL MOLE CT FR VD AMB X 100  ...       54.86   56.24
#
#       RESTRIÇÃO HOSPITALAR  CAP  CONFAZ 87  ICMS 0%  ANÁLISE RECURSAL  \
# 26305                  Sim  Sim        Sim      Sim               NaN
# 26306                  Não  Sim        Sim      Sim               NaN
# 26307                  Não  Sim        Sim      Sim               NaN
# 26308                  Não  Não        Sim      Não               NaN
# 26309                  Não  Não        Não      Não               NaN
#
#        LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 26305                                           Negativa
# 26306                                           Positiva
# 26307                                           Positiva
# 26308                                           Negativa
# 26309                                           Positiva
#
#        COMERCIALIZAÇÃO 2020              TARJA
# 26305                   Não  Tarja Vermelha(*)
# 26306                   Sim  Tarja Vermelha(*)
# 26307                   Sim    Tarja  Vermelha
# 26308                   Não    Tarja  Vermelha
# 26309                   Sim         Tarja -(*)
#
# [5 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['SUBSTÂNCIA', 'CNPJ', 'LABORATÓRIO', 'CÓDIGO GGREM', 'REGISTRO',
#        'EAN 1', 'EAN 2', 'EAN 3', 'PRODUTO', 'APRESENTAÇÃO',
#        'CLASSE TERAPÊUTICA', 'TIPO DE PRODUTO (STATUS DO PRODUTO)',
#        'REGIME DE PREÇO', 'PF Sem Impostos', 'PF 0%', 'PF 12%', 'PF 17%',
#        'PF 17% ALC', 'PF 17,5%', 'PF 17,5% ALC', 'PF 18%', 'PF 18% ALC',
#        'PF 20%', 'PMC 0%', 'PMC 12%', 'PMC 17%', 'PMC 17% ALC', 'PMC 17,5%',
#        'PMC 17,5% ALC', 'PMC 18%', 'PMC 18% ALC', 'PMC 20%',
#        'RESTRIÇÃO HOSPITALAR', 'CAP', 'CONFAZ 87', 'ICMS 0%',
#        'ANÁLISE RECURSAL',
#        'LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)',
#        'COMERCIALIZAÇÃO 2020', 'TARJA'],
#       dtype='object')

# %%
df_enx = df[df["CLASSE TERAPÊUTICA"] == "N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS"].copy()

# %%
df['PMC 12%'] = df['PMC 12%'].astype('float') 


df['PMC 12%']
# Out:
# 0          8.72
# 1        167.40
# 2         68.75
# 3         45.15
# 4         70.17
#           ...
# 26305       NaN
# 26306       NaN
# 26307       NaN
# 26308     12.66
# 26309     51.12
# Name: PMC 12%, Length: 26310, dtype: float64

# %%
lista = [df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].mean(),df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].max(),df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].min()]
df_medidas = pd.concat(lista, axis = 1)
display(df_medidas)
# Out:
# C:\Users\Fernanda\AppData\Local\Temp\ipykernel_14092\1147185830.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   lista = [df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].mean(),df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].max(),df[df['CLASSE TERAPÊUTICA'] =='N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUECOSAS'].min()]
#                                                                 0  \
# CÓDIGO GGREM                                         5.215829e+14
# REGISTRO                                            4.777627e+270
# EAN 1                                               3.760045e+271
# PF Sem Impostos                                      9.438843e+02
# PF 0%                                                1.056827e+03
# PF 12%                                               1.221206e+03
# PF 17%                                               1.305867e+03
# PF 17% ALC                                           1.137209e+03
# PF 17,5%                                             1.314985e+03
# PF 17,5% ALC                                         1.144102e+03
# PF 18%                                               1.324229e+03
# PF 18% ALC                                           1.151080e+03
# PF 20%                                               1.362556e+03
# PMC 0%                                               1.417806e+03
# PMC 12%                                              1.631410e+03
# PMC 17%                                              1.740784e+03
# PMC 17% ALC                                          1.572123e+03
# PMC 17,5%                                            1.752537e+03
# PMC 17,5% ALC                                        1.581655e+03
# PMC 18%                                              1.764447e+03
# PMC 18% ALC                                          1.591300e+03
# PMC 20%                                              1.813780e+03
# ANÁLISE RECURSAL                                              NaN
# SUBSTÂNCIA                                                    NaN
# CNPJ                                                          NaN
# LABORATÓRIO                                                   NaN
# EAN 2                                                         NaN
# EAN 3                                                         NaN
# PRODUTO                                                       NaN
# APRESENTAÇÃO                                                  NaN
# CLASSE TERAPÊUTICA                                            NaN
# TIPO DE PRODUTO (STATUS DO PRODUTO)                           NaN
# REGIME DE PREÇO                                               NaN
# RESTRIÇÃO HOSPITALAR                                          NaN
# CAP                                                           NaN
# CONFAZ 87                                                     NaN
# ICMS 0%                                                       NaN
# LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/C...            NaN
# COMERCIALIZAÇÃO 2020                                          NaN
# TARJA                                                         NaN
#
#                                                                                                     1  \
# CÓDIGO GGREM                                                                          541821020156503
# REGISTRO                                                                                1781701230122
# EAN 1                                                                                   7898152464206
# PF Sem Impostos                                                                               4852.73
# PF 0%                                                                                         5435.06
# PF 12%                                                                                        6280.69
# PF 17%                                                                                        6716.26
# PF 17% ALC                                                                                    5846.66
# PF 17,5%                                                                                      6763.17
# PF 17,5% ALC                                                                                   5882.1
# PF 18%                                                                                        6810.73
# PF 18% ALC                                                                                    5917.97
# PF 20%                                                                                        7007.92
# PMC 0%                                                                                        7290.94
# PMC 12%                                                                                       8389.65
# PMC 17%                                                                                       8952.27
# PMC 17% ALC                                                                                   8082.66
# PMC 17,5%                                                                                     9012.73
# PMC 17,5% ALC                                                                                 8131.66
# PMC 18%                                                                                       9073.99
# PMC 18% ALC                                                                                   8181.25
# PMC 20%                                                                                       9327.77
# ANÁLISE RECURSAL                                                                                 None
# SUBSTÂNCIA                                                         TANACETUM PARTHENIUM (L.) SCH.BIP.
# CNPJ                                                                               79.634.572/0001-82
# LABORATÓRIO                                                                   LIBBS FARMACÊUTICA LTDA
# EAN 2                                                                                          -
# EAN 3                                                                                          -
# PRODUTO                                                                                   TANACETO EC
# APRESENTAÇÃO                                                 85 MG + 500 MG COM REV CT BL AL AL X 02
# CLASSE TERAPÊUTICA                                  N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUE...
# TIPO DE PRODUTO (STATUS DO PRODUTO)                                                           Similar
# REGIME DE PREÇO                                                                              Regulado
# RESTRIÇÃO HOSPITALAR                                                                              Não
# CAP                                                                                               Não
# CONFAZ 87                                                                                         Não
# ICMS 0%                                                                                           Não
# LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/C...                                           Positiva
# COMERCIALIZAÇÃO 2020                                                                              Sim
# TARJA                                                                               Tarja Vermelha(*)
#
#                                                                                                     2
# CÓDIGO GGREM                                                                          500501901118417
# REGISTRO                                                                                1003301760012
# EAN 1                                                                                   7893736010053
# PF Sem Impostos                                                                                  8.39
# PF 0%                                                                                             9.4
# PF 12%                                                                                          10.86
# PF 17%                                                                                          11.62
# PF 17% ALC                                                                                      10.11
# PF 17,5%                                                                                         11.7
# PF 17,5% ALC                                                                                    10.17
# PF 18%                                                                                          11.78
# PF 18% ALC                                                                                      10.24
# PF 20%                                                                                          12.12
# PMC 0%                                                                                          12.61
# PMC 12%                                                                                         14.51
# PMC 17%                                                                                         15.49
# PMC 17% ALC                                                                                     13.98
# PMC 17,5%                                                                                       15.59
# PMC 17,5% ALC                                                                                   14.06
# PMC 18%                                                                                         15.69
# PMC 18% ALC                                                                                     14.16
# PMC 20%                                                                                         16.13
# ANÁLISE RECURSAL                                                                                 None
# SUBSTÂNCIA                                          CLORIDRATO DE METOCLOPRAMIDA;PARACETAMOL;MESIL...
# CNPJ                                                                               17.159.229/0001-76
# LABORATÓRIO                                                       ACHÉ LABORATÓRIOS FARMACÊUTICOS S.A
# EAN 2                                                                                          -
# EAN 3                                                                                          -
# PRODUTO                                                                                      CEFALIUM
# APRESENTAÇÃO                                            (1,0 + 100,0 + 350,0) MG COM CT BL AL AL X 12
# CLASSE TERAPÊUTICA                                  N2C9 - TODOS AS OUTRAS PREPARAÇÕES ANTIENXAQUE...
# TIPO DE PRODUTO (STATUS DO PRODUTO)                                                         Biológico
# REGIME DE PREÇO                                                                              Liberado
# RESTRIÇÃO HOSPITALAR                                                                              Não
# CAP                                                                                               Não
# CONFAZ 87                                                                                         Não
# ICMS 0%                                                                                           Não
# LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/C...                                           Negativa
# COMERCIALIZAÇÃO 2020                                                                              Não
# TARJA                                                                                 Tarja  Vermelha

# %%
media = df_enx['PMC 12%'].mean()
max = df_enx['PMC 12%'].max()
min = df_enx['PMC 12%'].min()

display(df_enx[df_enx['PMC 12%'] == media])
display(df_enx[df_enx['PMC 12%'] ==max])
display(df_enx[df_enx['PMC 12%'] ==min])
# Out:
# Empty DataFrame
# Columns: [SUBSTÂNCIA, CNPJ, LABORATÓRIO, CÓDIGO GGREM, REGISTRO, EAN 1, EAN 2, EAN 3, PRODUTO, APRESENTAÇÃO, CLASSE TERAPÊUTICA, TIPO DE PRODUTO (STATUS DO PRODUTO), REGIME DE PREÇO, PF Sem Impostos, PF 0%, PF 12%, PF 17%, PF 17% ALC, PF 17,5%, PF 17,5% ALC, PF 18%, PF 18% ALC, PF 20%, PMC 0%, PMC 12%, PMC 17%, PMC 17% ALC, PMC 17,5%, PMC 17,5% ALC, PMC 18%, PMC 18% ALC, PMC 20%, RESTRIÇÃO HOSPITALAR, CAP, CONFAZ 87, ICMS 0%, ANÁLISE RECURSAL, LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS), COMERCIALIZAÇÃO 2020, TARJA]
# Index: []
#
# [0 rows x 40 columns]
#           SUBSTÂNCIA                CNPJ               LABORATÓRIO  \
# 13752  GALCANEZUMABE  43.940.618/0001-44  ELI LILLY DO BRASIL LTDA
# 13755  GALCANEZUMABE  43.940.618/0001-44  ELI LILLY DO BRASIL LTDA
#
#           CÓDIGO GGREM       REGISTRO          EAN 1       EAN 2       EAN 3  \
# 13752  507620040020807  1126002000038  7896382708565      -           -
# 13755  507620040021307  1126002000062  7896382708596      -           -
#
#         PRODUTO                                       APRESENTAÇÃO  ...  \
# 13752  EMGALITY  120 MG/ML SOL INJ CT 3 SER PREENC VD TRANS X 1...  ...
# 13755  EMGALITY  120 MG/ML SOL INJ CT 3 SER PREENC VD TRANS X 1 ML  ...
#
#       PMC 18% ALC  PMC 20% RESTRIÇÃO HOSPITALAR  CAP  CONFAZ 87  ICMS 0%  \
# 13752     8181.25  9327.77                  Não  Não        Não      Não
# 13755     8181.25  9327.77                  Não  Não        Não      Não
#
#        ANÁLISE RECURSAL  \
# 13752               NaN
# 13755               NaN
#
#        LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 13752                                           Negativa
# 13755                                           Negativa
#
#        COMERCIALIZAÇÃO 2020       TARJA
# 13752                   Não  Tarja -(*)
# 13755                   Não  Tarja -(*)
#
# [2 rows x 40 columns]
#                                        SUBSTÂNCIA                CNPJ  \
# 24505  PARACETAMOL;CAFEÍNA;ÁCIDO ACETILSALICÍLICO  61.082.426/0002-07
#
#                                              LABORATÓRIO     CÓDIGO GGREM  \
# 24505  COSMED INDUSTRIA DE COSMETICOS E MEDICAMENTOS ...  540921050047307
#
#             REGISTRO          EAN 1       EAN 2       EAN 3          PRODUTO  \
# 24505  1781701230033  7896094920910      -           -       DORIL ENXAQUECA
#
#                                           APRESENTAÇÃO  ... PMC 18% ALC  \
# 24505  250 MG + 250 MG + 65 MG COM REV CT BL AL AL X 8  ...       14.16
#
#       PMC 20% RESTRIÇÃO HOSPITALAR  CAP  CONFAZ 87  ICMS 0%  ANÁLISE RECURSAL  \
# 24505   16.13                  Não  Não        Não      Não               NaN
#
#        LISTA DE CONCESSÃO DE CRÉDITO TRIBUTÁRIO (PIS/COFINS)  \
# 24505                                           Negativa
#
#        COMERCIALIZAÇÃO 2020                            TARJA
# 24505                   Não  Tarja Venda Livre/Sem Tarja (*)
#
# [1 rows x 40 columns]

# %%
df.groupby(by=['TARJA']).size().reset_index(name = 'counts')
# Out:
#                              TARJA  counts
# 0                           - (*)       49
# 1                     Tarja  Preta     173
# 2                  Tarja  Vermelha    7132
# 3                       Tarja -(*)    1571
# 4                   Tarja Preta(*)     379
# 5                Tarja Venda Livre    1299
# 6  Tarja Venda Livre/Sem Tarja (*)    1551
# 7               Tarja Vermelha (*)    3878
# 8                Tarja Vermelha(*)   10278

# %%
df.groupby(by=['LABORATÓRIO']).size().reset_index(name = 'counts').sort_values(by=['counts'],ascending=False).head(10)
# Out:
#                                          LABORATÓRIO  counts
# 78                                           EMS S/A    1476
# 4                ACHÉ LABORATÓRIOS FARMACÊUTICOS S.A    1122
# 219                       PRATI DONADUZZI & CIA LTDA     883
# 172       LEGRAND PHARMA INDÚSTRIA FARMACÊUTICA LTDA     875
# 104                         GERMED FARMACEUTICA LTDA     870
# 231                 SANOFI MEDLEY FARMACÊUTICA LTDA.     864
# 81                       EUROFARMA LABORATÓRIOS S.A.     779
# 201                    NOVA QUIMICA FARMACÊUTICA S/A     755
# 102                GEOLAB INDÚSTRIA FARMACÊUTICA S/A     736
# 66   CRISTÁLIA PRODUTOS QUÍMICOS FARMACÊUTICOS LTDA.     713
