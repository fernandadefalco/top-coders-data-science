# %%
import json
import os.path
import sys

def obter_dados():
    '''
    Essa função carrega os dados dos produtos e retorna uma lista de dicionários, onde cada dicionário representa um produto.
    NÃO MODIFIQUE essa função.
    '''
    with open(os.path.join(sys.path[0], 'dados.json'), 'r') as arq:
        dados = json.loads(arq.read())
    return dados

def categorias_lista(dados):
    lista_categorias=[]
    for dicionario in dados:
        lista_categorias.append(dicionario['categoria'])
    
    return lista_categorias

def ids_lista(dados):
    lista_ids = []
    for dicionario in dados:
        lista_ids.append(dicionario['id'])
    
    return lista_ids

def precos_lista(dados):
    lista_precos = []
    for dicionario in dados:
        lista_precos.append(dicionario['preco'])
    
    return lista_precos

def listar_categorias(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista contendo todas as categorias dos diferentes produtos.
    Cuidado para não retornar categorias repetidas.    
    '''
#     lista_apoio =[]
#     lista_categorias=[]
#     #Forma uma lista com os valores do dicionário - [['203831c4','190','moveis'],['2038e3c4','190','moveis']]
#     for i in range(0,len(dados)):
#         lista_apoio.append(list(dados[i].values()))
#     #Forma uma lista com as categorias, não repetidas
#     for i in range(0,len(lista_apoio)):
#         if lista_apoio[i][2] not in lista_categorias:
#             lista_categorias.append(lista_apoio[i][2])
    
#     return lista_categorias
    lista_sem_repeticao=[]
    for item in categorias_lista(dados):
        if item not in lista_sem_repeticao:
            lista_sem_repeticao.append(item)
    
    return lista_sem_repeticao
    

def listar_por_categoria(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar uma lista contendo todos os produtos pertencentes à categoria dada.
    '''
    indices = []
    for i in range(0,len(categorias_lista(dados))):
        if categorias_lista(dados)[i] == categoria:
            indices.append(i)
    
    lista_produtos_categoria = []
    for i in indices:
        lista_produtos_categoria.append(ids_lista(dados)[i])
    
    return lista_produtos_categoria

def produto_mais_caro(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais caro da categoria dada.
    '''
    ...


def produto_mais_barato(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais caro da categoria dada.
    '''
    ...

def top_10_caros(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais caros.
    '''
    ...

def top_10_baratos(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais caros.
    '''
    ...

def menu(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá, em loop, realizar as seguintes ações:
    - Exibir as seguintes opções:
        1. Listar categorias
        2. Listar produtos de uma categoria
        3. Produto mais caro por categoria
        4. Produto mais barato por categoria
        5. Top 10 produtos mais caros
        6. Top 10 produtos mais baratos
        0. Sair
    - Ler a opção do usuário.
    - No caso de opção inválida, imprima uma mensagem de erro.
    - No caso das opções 2, 3 ou 4, pedir para o usuário digitar a categoria desejada.
    - Chamar a função adequada para tratar o pedido do usuário e salvar seu retorno.
    - Imprimir o retorno salvo. 
    O loop encerra quando a opção do usuário for 0.
    '''
    ...


# Programa Principal - não modificar!
d = obter_dados()
# menu(d)
# listar_categorias(d)
listar_por_categoria(d,'pcs')
# Out:
# ['ca728758-9027-4af2-8253-7cbbf50083e6',
#  'bbd0eaf5-4468-475e-a185-675fe7f77c6d',
#  'c2b9c624-1914-40c2-b877-f89ac124eff0',
#  '73596fa0-2c02-4ee4-ac98-4416a8ac2e16',
#  'da99f07f-224a-4160-a1fa-f1bcdc23914b',
#  '55973559-bac9-44b1-ae50-5de769b492cc',
#  '5b82e78b-aa89-4f52-b0a4-c0f36c707a59',
#  '29b584e9-5071-4462-8ebb-2c456c6c6fc8',
#  'd1d2bf0e-054d-40b8-afc3-eb93b8e45950',
#  'c6247533-dc8d-4d65-b64f-7629204dea17',
#  'd1697d4a-6fdb-4db6-a178-207022ed5a5e']

# %%
dados =[{'id': 'ca728758-9027-4af2-8253-7cbbf50083e6',
  'preco': '1622.50',
  'categoria': 'pcs'},
 {'id': '6dfb3cd6-aa63-4238-81b2-8df5b454f587',
  'preco': '4483.69',
  'categoria': 'livros_importados'},
 {'id': 'e84db4a9-d3e6-4217-97c1-6d2950fc9e39',
  'preco': '4427.15',
  'categoria': 'pet_shop'},
 {'id': 'cdb8a274-1de6-4919-9534-9b83b252caf3',
  'preco': '3229.52',
  'categoria': 'eletronicos'},
 {'id': '1464f8e7-894c-48d6-a8ad-f12854a9dd9f',
  'preco': '3461.74',
  'categoria': 'construcao_ferramentas_ferramentas'},
 {'id': 'b29423e3-52ff-490b-a4be-56fd738dfb27',
  'preco': '577.59',
  'categoria': 'pet_shop'},
 {'id': '6f6113df-588d-410b-8e41-0fe00072a9b6',
  'preco': '529.48',
  'categoria': 'perfumaria'},
 {'id': '702af712-8279-4136-a06d-e148381d6e29',
  'preco': '2361.78',
  'categoria': 'agro_industria_e_comercio'},
 {'id': '8f0035cf-99c0-4592-afc4-4ad0fe742495',
  'preco': '4170.37',
  'categoria': 'alimentos'},
 {'id': '77ad22b5-5017-4730-b2b6-bd1a84d68789',
  'preco': '3597.56',
  'categoria': 'portateis_casa_forno_e_cafe'},
 {'id': '26cea180-8ef3-4441-9707-73713f3e933f',
  'preco': '4.55',
  'categoria': 'pcs'},
 {'id': '5dcb267d-f4f8-4af2-9bc0-2ff907174499',
  'preco': '4571.00',
  'categoria': 'fashion_bolsas_e_acessorios'},
 {'id': '55921514-369b-4445-bc51-ea979759662b',
  'preco': '2773.55',
  'categoria': 'utilidades_domesticas'},
 {'id': 'bbd0eaf5-4468-475e-a185-675fe7f77c6d',
  'preco': '288.74',
  'categoria': 'pcs'}]

# listar_por_categoria(dados, 'pcs')

categ =  listar_por_categoria(dados, 'pcs')
minimo = categ[0]
for i in range(0,len(categ)-1):
        if float(categ[i+1]['preco']) < float(categ[i]['preco']):
                minimo = categ[i+1]
        
print(minimo)
# Out:
# {'id': '26cea180-8ef3-4441-9707-73713f3e933f', 'preco': '4.55', 'categoria': 'pcs'}

# %%
import json
import os.path
import sys

def obter_dados():
    '''
    Essa função carrega os dados dos produtos e retorna uma lista de dicionários, onde cada dicionário representa um produto.
    NÃO MODIFIQUE essa função.
    '''
    with open(os.path.join(sys.path[0], 'dados.json'), 'r') as arq:
        dados = json.loads(arq.read())
    return dados

def lista_categorias(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista contendo todas as categorias dos diferentes produtos.
    Cuidado para não retornar categorias repetidas.    
    '''
    lista_sem_repeticao = []
    lista_categoria = []
    for i in range(0,len(dados)):
        lista_categoria.append(dados[i]['categoria'])
        if dados[i]['categoria'] not in lista_sem_repeticao:
            lista_sem_repeticao.append(dados[i]['categoria'])
    
    return lista_sem_repeticao
    

def listar_por_categoria(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar uma lista contendo todos os produtos pertencentes à categoria dada.
    '''
    lista_produtos_categoria = []
    for i in range(0,len(dados)):
        if dados[i]['categoria'] == categoria:
            lista_produtos_categoria.append(dados[i])
    
    return lista_produtos_categoria

def produto_mais_caro(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais caro da categoria dada.
    '''
    
    categ = listar_por_categoria(dados, categoria)
    maximo = categ[0]
    for i in range(0,len(categ)-1):
        if float(categ[i+1]['preco']) > float(maximo['preco']):
                maximo = categ[i+1]
    
    return maximo

def produto_mais_barato(dados, categoria):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais barato da categoria dada.
    '''
    categ = listar_por_categoria(dados, categoria)
    minimo = categ[0]
    for i in range(0,len(categ)-1):
        if float(categ[i+1]['preco']) < float(minimo['preco']):
                minimo = categ[i+1]
    
    return minimo

def top_10_caros(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais caros.
    '''
    lista_caros = []
    while len(lista_caros) < 10:   
        maximo = dados[0]
        for i in range(0,len(dados)-1):
                    if float(dados[i+1]['preco']) > float(maximo['preco']):
                        maximo = dados[i+1]     
        lista_caros.append(maximo)
        dados.remove(maximo)
        
    return lista_caros

def top_10_baratos(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais caros.
    '''
    lista_baratos = []
    while len(lista_baratos) < 10:   
        minimo = dados[0]
        for i in range(0,len(dados)-1):
                    if float(dados[i+1]['preco']) < float(minimo['preco']):
                        minimo = dados[i+1]     
        lista_baratos.append(minimo)
        dados.remove(minimo)
        
    return lista_baratos

def menu(dados):
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá, em loop, realizar as seguintes ações:
    - Exibir as seguintes opções:
        1. Listar categorias
        2. Listar produtos de uma categoria
        3. Produto mais caro por categoria
        4. Produto mais barato por categoria
        5. Top 10 produtos mais caros
        6. Top 10 produtos mais baratos
        0. Sair
    - Ler a opção do usuário.
    - No caso de opção inválida, imprima uma mensagem de erro.
    - No caso das opções 2, 3 ou 4, pedir para o usuário digitar a categoria desejada.
    - Chamar a função adequada para tratar o pedido do usuário e salvar seu retorno.
    - Imprimir o retorno salvo. 
    O loop encerra quando a opção do usuário for 0.
    '''
    print('''------------------MENU------------------
                 Escolha uma opção:
                 1. Listar categorias
                 2. Listar produtos de uma categoria
                 3. Produto mais caro por categoria
                 4. Produto mais barato por categoria
                 5. Top 10 produtos mais caros
                 6. Top 10 produtos mais baratos
                 0. Sair''')
    opcao = int(input("Selecione a opção desejada: "))
    while opcao not in range(0,7):
        opcao = int(input("Opção inválida, selecione uma das opções da lista: "))

    if opcao == 0:
        resposta = "********** Fim do programa **********"
    elif opcao == 1:
        resposta = lista_categorias(dados)
    elif opcao in (2,3,4):
        categoria = (input("Insira a categoria desejada: "))
        if opcao == 2:
            resposta = listar_por_categoria(dados, categoria)
        if opcao == 3:
            resposta = produto_mais_caro(dados, categoria)
        if opcao == 4:
            resposta = produto_mais_barato(dados, categoria)
    elif opcao == 5:
        resposta = top_10_caros(dados)
    else:
        resposta = top_10_baratos(dados)
    print(resposta)
    
# Programa Principal - não modificar!
d = obter_dados()
# %memit menu(d)

# lista_categorias(d)
validacao = input("Gostaria de escolher novamente? (S/N)").upper()
while validacao == "S":
    menu(d)
    validacao = input("Gostaria de escolher novamente? (S/N)").upper()

# %%
# %memit top_10_caros(obter_dados())
# Out:
# peak memory: 77.01 MiB, increment: 0.04 MiB

# %%
dados= [{'id': 'ca728758-9027-4af2-8253-7cbbf50083e6',
  'preco': '1622.50',
  'categoria': 'pcs'},
 {'id': 'bbd0eaf5-4468-475e-a185-675fe7f77c6d',
  'preco': '288.74',
  'categoria': 'pcs'},
 {'id': 'c2b9c624-1914-40c2-b877-f89ac124eff0',
  'preco': '3710.03',
  'categoria': 'pcs'},
 {'id': '73596fa0-2c02-4ee4-ac98-4416a8ac2e16',
  'preco': '622.91',
  'categoria': 'pcs'},
 {'id': 'da99f07f-224a-4160-a1fa-f1bcdc23914b',
  'preco': '1149.08',
  'categoria': 'pcs'},
 {'id': '55973559-bac9-44b1-ae50-5de769b492cc',
  'preco': '1762.32',
  'categoria': 'pcs'},
 {'id': '5b82e78b-aa89-4f52-b0a4-c0f36c707a59',
  'preco': '4034.46',
  'categoria': 'pcs'},
 {'id': '29b584e9-5071-4462-8ebb-2c456c6c6fc8',
  'preco': '10000.79',
  'categoria': 'pcs'},
 {'id': 'd1d2bf0e-054d-40b8-afc3-eb93b8e45950',
  'preco': '1903.47',
  'categoria': 'pcs'},
 {'id': 'c6247533-dc8d-4d65-b64f-7629204dea17',
  'preco': '1916.93',
  'categoria': 'pcs'},
 {'id': 'd1697d4a-6fdb-4db6-a178-207022ed5a5e',
  'preco': '3660.70',
  'categoria': 'pcs'}]

lista_caros = []
while len(lista_caros)<3:   
        maximo = dados[0]
        for i in range(0,len(dados)-1):
                    if float(dados[i+1]['preco']) > float(maximo['preco']):
                        maximo = dados[i+1]
        
        lista_caros.append(maximo)
        dados.remove(maximo)
print(lista_caros)
# Out:
# [{'id': '29b584e9-5071-4462-8ebb-2c456c6c6fc8', 'preco': '10000.79', 'categoria': 'pcs'}, {'id': '5b82e78b-aa89-4f52-b0a4-c0f36c707a59', 'preco': '4034.46', 'categoria': 'pcs'}, {'id': 'c2b9c624-1914-40c2-b877-f89ac124eff0', 'preco': '3710.03', 'categoria': 'pcs'}]

# %%
# !pip install memory_profiler
# %load_ext memory_profiler
from memory_profiler import profile
# Out:
# ...
#   Created wheel for memory-profiler: filename=memory_profiler-0.60.0-py3-none-any.whl size=31279 sha256=1ace1fed2afa9c5a157e6472dba1c566afdf1c14c2ed5afe7106d8ce24c3c32d
#   Stored in directory: c:\users\fernanda\appdata\local\pip\cache\wheels\01\ca\8b\b518dd2aef69635ad6fcab87069c9c52f355a2e9c5d4c02da9
# Successfully built memory-profiler
# ...
